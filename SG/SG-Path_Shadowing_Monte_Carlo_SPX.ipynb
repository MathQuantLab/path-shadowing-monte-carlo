# %% [markdown]
# # Path Shadowing Monte Carlo on SPX Index

# %% [markdown]
# **Importing necessary libraries**

# %%
import yfinance as yf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import norm

from sklearn.neighbors import KernelDensity

from shadowing import (
    Softmax,
    compute_smile,
    PathShadowing,
    Foveal,
    RelativeMSE,
    PredictionContext,
    ArrayType,
)

from scatspectra.data import snp_data

import warnings

warnings.filterwarnings("ignore")  # Display all warnings

# %% [markdown]
# ## SPX Index Data
# We chose to get the SPX index data from Yahoo Finance and use the `yfinance` library to get it. Data have been downloaded from 2010-01-01 to 2024-01-01, and the adjusted close price has been used as the price of the index.

# %% [markdown]
# ### From Yahoo Finance:

# %%
# importing SPX data from yahoo finance from 2010 to 2020
spx = yf.download("^GSPC", "2010-01-01", "2024-01-01")
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
spx
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2010-01-04  1116.560059  1133.869995  1116.560059  1132.989990  1132.989990
# 2010-01-05  1132.660034  1136.630005  1129.660034  1136.520020  1136.520020
# 2010-01-06  1135.709961  1139.189941  1133.949951  1137.140015  1137.140015
# 2010-01-07  1136.270020  1142.459961  1131.319946  1141.689941  1141.689941
# 2010-01-08  1140.520020  1145.390015  1136.219971  1144.979980  1144.979980
# ...                 ...          ...          ...          ...          ...
# 2023-12-22  4753.919922  4772.939941  4736.770020  4754.629883  4754.629883
# 2023-12-26  4758.859863  4784.720215  4758.450195  4774.750000  4774.750000
# 2023-12-27  4773.450195  4785.390137  4768.899902  4781.580078  4781.580078
# 2023-12-28  4786.439941  4793.299805  4780.979980  4783.350098  4783.350098
# 2023-12-29  4782.879883  4788.430176  4751.990234  4769.830078  4769.830078
#
#                 Volume
# Date
# 2010-01-04  3991400000
# 2010-01-05  2491020000
# 2010-01-06  4972660000
# 2010-01-07  5270680000
# 2010-01-08  4389590000
# ...                ...
# 2023-12-22  3046770000
# 2023-12-26  2513910000
# 2023-12-27  2748450000
# 2023-12-28  2698860000
# 2023-12-29  3126060000
#
# [3522 rows x 6 columns]

# %% [markdown]
# ### From Wall Street Journal:

# %%
snp_data[' Close']
# Out:
# Date
# 2024-02-07    4995.06
# 2024-02-06    4954.23
# 2024-02-05    4942.81
# 2024-02-02    4958.61
# 2024-02-01    4906.19
#                ...
# 2000-01-07    1441.47
# 2000-01-06    1403.45
# 2000-01-05    1402.11
# 2000-01-04    1399.42
# 2000-01-03    1455.22
# Name:  Close, Length: 6063, dtype: float64

# %%
# Visualisation of the price subplots
fig, ax = plt.subplots(2, 1, figsize=(15, 10))
ax[0].plot(spx["Adj Close"], label="S&P 500")
ax[0].set_title("S&P 500 from Yahoo Finance data")
ax[0].set_xlabel("Date")
ax[0].set_ylabel("Price")
ax[0].legend()

ax[1].plot(snp_data[" Close"], label="S&P 500")
ax[1].set_title("S&P 500 from Wall Street Journal data")
ax[1].set_xlabel("Date")
ax[1].set_ylabel("Price")
ax[1].legend()
plt.show()

# %% [markdown]
# **Log-returns**

# %%
# log returns of the adjusted close price
spx["log_returns"] = np.log(spx["Adj Close"] / spx["Adj Close"].shift(1))
# removing the first row with NaN
spx = spx.iloc[1:]

# %%
# plotting the log returns
plt.figure(figsize=(20, 10))
plt.plot(spx["log_returns"], color="red", label="SPX log returns")
plt.title("SPX Log Returns")
plt.xlabel("Date")
plt.ylabel("Log Returns")
plt.hlines(y=0, xmin=spx.index[0], xmax=spx.index[-1], color="black", label="zero")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(20, 10))
plt.plot(spx["log_returns"][:100], color="red", label="SPX log returns")
plt.title("SPX Log Returns")
plt.xlabel("Date")
plt.ylabel("Log Returns")
plt.legend()
plt.show()

# %% [markdown]
# **Standard statics of log-returns in the SPX index**

# %%
# standard statistics of the log returns
spx["log_returns"].describe()
# Out:
# count    3521.000000
# mean        0.000408
# std         0.011068
# min        -0.127652
# 25%        -0.003891
# 50%         0.000643
# 75%         0.005677
# max         0.089683
# Name: log_returns, dtype: float64

# %%
# histogram of the log returns with xmin and xmax between -0.05 and 0.05
plt.figure(figsize=(20, 10))
plt.hist(
    spx["log_returns"],
    bins=100,
    density=True,
    color="blue",
    range=(-0.05, 0.05),
    label="Log Returns distribution",
)
# fit a gaussian distribution to the log returns and plot it
mu, std = norm.fit(spx["log_returns"])
xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
p = norm.pdf(x, mu, std)
plt.plot(x, p, "k", linewidth=2, color="red", label="Gaussian Fit")
plt.legend()
plt.title("SPX Log Returns Distribution with Gaussian Fit")
plt.show()
print("Fit results: mu = %.2f,  std = %.2f" % (mu, std))
# Out:
# Fit results: mu = 0.00,  std = 0.01

# %% [markdown]
# As expected the distribution of the log-prices of the SPX Index are not gaussian.

# %% [markdown]
# **Stationnarity of the log-returns**
# We assume that the real world is at least approximatevly stationary, in the sense that it can be approximated by a statistical model with fixed, time-independent parameters.
#
# We can verify this assumption by looking at the autocorrelation function of the log-returns. If the log-returns are stationary, the autocorrelation function should decay to zero as the lag increases.

# %%
# Autocorrelation of the log returns to test the stationarity of the time series
# from statsmodels.graphics.tsaplots import plot_acf
# plot_acf(spx['log_returns'], lags=20)
# plt.show()

# %%
# Testing the stationarity of the log returns

# ADF test
from statsmodels.tsa.stattools import adfuller

result_ADF = adfuller(spx["log_returns"])
print("ADF Statistic: %f" % result_ADF[0])
print("ADF p-value: %f" % result_ADF[1])

# KPSS test
from statsmodels.tsa.stattools import kpss

result_KPSS = kpss(spx["log_returns"])
print("KPSS Statistic: %f" % result_KPSS[0])
print("KPSS p-value: %f" % result_KPSS[1])
p_value_kpss = result_KPSS[1]
if p_value_kpss <= 0.05:
    print("The log-prices may not be stationary.")
else:
    print("The log-prices are likely stationary.")
# Out:
# ADF Statistic: -12.908829
# ADF p-value: 0.000000
# KPSS Statistic: 0.018274
# KPSS p-value: 0.100000
# The log-prices are likely stationary.
# /var/folders/zw/dpjp09bn4_l8yjw9zyyrfcmr0000gn/T/ipykernel_68336/4244847999.py:13: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   result_KPSS = kpss(spx["log_returns"])

# %% [markdown]
# ## Path Shadowing on SPX Index

# %% [markdown]
# Given the past history $x_{past}$ at current
# time t, a model-free method for predicting the unknown future
# $x_{future}$ is to look for occurrences similar to $x_{past}$ in the historical
# realization of log-prices. If such occurrences can be found,
# what happened thereafter provides some information about the
# unknown future $x_{future}$  at the current time t.
#
# But finding exact occurrences of course happens with vanishing
# probability.
#
# **Path Shadowing**:
# We introduce an embedding $h(\tilde{x}_{past})$
# that reduces the dimensionality of past trajectories and define shadowing paths as paths $x$ whose past history $h(x_{past})$ is close to $h(\tilde{x}_{past})$ in a certain sense.
# With:
# - $\tilde{x}_{past}$ : representing the current past history
# - $x_{past}$ : representing the scanned paths.
# Such path $x_{past}$ *shadow* $\tilde{x}_{past}$, i.e they provide insights on the future.
#
# **Path Shadowing Monte-Carlo**
# The shadowing paths are used as inputs for the proposed Monte-Carlo method. The method is based on the idea of generating a large number of shadowing paths and then using them to estimate the distribution of the future $x_{future}$ at the current time t.
#
# So for a quantity $q(x_{future})$ of interest, the optimal estimate of $q(\tilde{x}_{future})$ for the mean square error as a function of the observed past history $\tilde{x}_{past}$ is given by the conditional expectation:
# $$
# E[q(x) | {x}_{past} = \tilde{x}_{past}]
# $$
# where $E$ is the expectation under the true distribution $p(x)$ of log-prices.
#
# **The goal** is to estimate the conditional expectation using the Monte-Carlo method. The idea is to generate a large number of shadowing paths and then use them to estimate the conditional expectation.
#
# **The Monte-Carlo method**:
# The Monte Carlo method estimates the conditional expectation by averaging the quantity of interest over a large number of shadowing paths.
# 1. Generate a large number of shadowing paths $x^1, x^2, ..., x^N$.
# 2. For each path $x_i$, compute the quantity of interest $q(x^i)$.
# 3. The estimate of the conditional expectation is then given by the sample mean:
# $$
# \frac{1}{N} \sum_{i=1}^{N} q(x^i)
# $$
# which converges to the true conditional expectation as the number of shadowing paths goes to infinity.
#
# **The problem**:
# The Monte-Carlo method is computationally expensive, as it requires generating a large number of shadowing paths. It requires a large number of paths $x^i$ such that $x^k_{past} = \tilde x_{past}$ which is impossible for data of finite size.
#
# **Solution**: We consider paths $x$ whose past $x_{past}$ is close to $\tilde x_{past}$ in a certain sense. To tackle this problem, we relax strict conditioning on $\tilde x_{past}$ and consider paths x whose past $x_{past}$ is close to $\tilde x_{past}$ in a certain sense.
# In order to account for possible long-range dependencies, we would like to consider a long past $\tilde x_{past}$. However, finding paths $x_{past}$ at a given distance from $\tilde x_{past}$ becomes exponentially difficult as the size of the path grows : this is the curse of dimensionality. In order to control the dimension, we consider a path embedding $h(x_{past}) \in R^M$. Given a threshold $\eta > 0$ we define the set of *$\eta$-shadowing paths* as
# $$ H_{\eta}(\tilde x_{past}) = \{ x \in R^N: || h(x_{past}) - h(\tilde x_{past}) || \leq \eta \}$$
#
# The idea is for a certain small $\eta$, paths in $H_{\eta}(\tilde x_{past})$ can be considered as true realizations of the process that can be used faithfully compute observables.

# %% [markdown]
# ### Path Shadowing Monte-Carlo:
# Th Monte-Carlo method on shadowing paths is a predective method that uses the past history of the log-prices to estimate the future log-prices. So it is a **predictive method**.
#
# All paths do not have the same weights, unlike the traditional Monte-Carlo method, since $|| h(x_{past}^k) - h(\tilde x_{past}) ||$ is not uniform in k. The weights are given by the distance between the past history of the path and the observed past history.
#
# It gives the following estimator:
# $$\frac{1}{n} \sum_{k=1}^{n} w_{k}q(x^k)$$
# where $w_k$ represents the weight which is called the "Nadaraya–Watson estimator" of the path $x^k$.
#
# We can choose Gaussian weights such that:
# $$w_k = c exp\lbrack-\frac{|| h(x_{past}^k) - h(\tilde x_{past}) ||}{2\eta^2}\rbrack$$
#
# So the set of shadowing path can be defined as: **the set of all paths that are one standard deviation away from the observed past history $\tilde x_{past}$ for the Gaussian kernel**.
#
# $\Longrightarrow$ **Path Shadowing Monte-Carlo can be seen as a kernel method on log-price paths using a Gaussian kernel.**

# %% [markdown]
# # Volatility Prediction using Path Shadowing Monte-Carlo

# %% [markdown]
# **Prediction of the future realized volatility over T days:**
# $$q_T(x) = \frac{252}{T} \sum_{u=t+1}^{t+T} |\delta x_u|^2$$
# for different values of T.
#
# For our analysis, we will consider *T = 1, 7, 25, 75 and 150 days*.

# %% [markdown]
# ### Path Shadowing
# Using observed log-returns of the SPX Index during the year 2022, we identify the most similar paths within the generated dataset.
#
# ##### 1. Embedding function
# To do this we use an **embedding function $h$** that leverages the scale invariance of the log-returns in the same way of the Scattering Spectra framework.
#
# The function $h$ depends on two parameters $\alpha$ and $\beta$.
#
# We test first using the same parameters as those used in the tutorial found in Github repository of the authors of the paper; which are $\alpha = 1.15$ and $\beta = 0.9$. But in our context we look at the whole year in the observed past.

# %%
# embedding for dimensionality reduction
embedding = Foveal(
    alpha=1.15,  # cover the past at exponential speed
    beta=0.9,  # look with a weight power-law decay of 0.9
    max_context=126,  # look at last year in the observed past
)

# %%
len(embedding.kernel)
# Out:
# 34

# %%
embedding.kernel.shape[-1]
# Out:
# 126

# %% [markdown]
# **Mesure of distance:**
# We use the RMSE as a measure of distance between the observed past history and the past history of the paths.
#
# ##### RMSE
# Relative Mean Squared Error (Relative MSE) is a statistical metric used to quantify the dissimilarity between two paths or time series data sets. It is particularly useful in the context of path shadowing, where the goal is to assess how closely one path follows another.
#
# Mathematically, the Relative MSE is defined as the average squared difference between corresponding points in the two paths, normalized by the variance of the reference path. It is calculated using the following formula:
#
# $$\text{Relative MSE} = \frac{1}{N} \sum_{i=1}^{N} \left(\frac{{y_i - \hat{y}_i}}{y_i}\right)^2 $$
#
# Where:
# - $N$ is the total number of data points in the paths.
# - $y_i$ represents the value of the reference path at time $i$.
# - $\hat{y}_i$ represents the value of the shadowing path at time $i$.
#
# By normalizing the squared differences by the reference path's variance, the Relative MSE accounts for the variability in the reference path. This allows for a comparison that is relative to the scale and magnitude of the reference path, making the metric suitable for assessing the similarity or dissimilarity between paths regardless of their absolute values.
#
# A lower Relative MSE indicates a closer match between the paths, while a higher Relative MSE suggests greater deviation or discrepancy between them. Therefore, Relative MSE serves as a quantitative measure of path similarity in the context of path shadowing analysis.

# %%
# distance between embedded paths
distance = RelativeMSE()

# %% [markdown]
# The Path Shadowing is a non-local method : the shadow paths $x^k$ may be fare away in the past from $\tilde x_{past}$.

# %%
# object for path shadowing
obj = PathShadowing(
    embedding=embedding,
    distance=distance,
    dataset=spx["log_returns"],
    context=PredictionContext(horizon=252),  # the size of such paths in the future
)

# %%
np.array(spx["log_returns"])
# Out:
# array([ 0.00311083,  0.00054537,  0.00399322, ...,  0.00142944,
#         0.00037011, -0.00283048])

# %%
# PERFORM PATH SHADOWING
distances, close_paths = obj.shadow(
    np.array(spx["log_returns"][:126]),
    k=8192,  # the number of closest paths (from generated dataset) to retain
    n_splits=8,
    cuda=False,  # set to True, if GPU available, for accelarations
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[41], line 2
#       1 # PERFORM PATH SHADOWING
# ----> 2 distances, close_paths = obj.shadow(
#       3     np.array(spx["log_returns"][:126]),
#       4     k=8192,  # the number of closest paths (from generated dataset) to retain
#       5     n_splits=8,
#       6     cuda=False,  # set to True, if GPU available, for accelarations
#       7 )
#
# File ~/Documents/GitHub/path-shadowing-monte-carlo/.venv/lib/python3.10/site-packages/shadowing/path_shadowing/path_shadowing.py:188, in PathShadowing.shadow(self, x_context, k, n_splits, cuda)
#     185 x_context = _torch(x_context)
#     187 # dataset scanned for shadowing paths
# --> 188 x_dataset = _dim_array(self.dataset)
#     189 x_dataset = _torch(x_dataset)
#     191 # computing k-smallest distances
#
# File ~/Documents/GitHub/path-shadowing-monte-carlo/.venv/lib/python3.10/site-packages/shadowing/path_shadowing/path_shadowing.py:22, in _dim_array(x)
#      20     return x
#      21 if x.ndim == 1:  # assume time is provided
# ---> 22     return x[None, None, :]
#      23 if x.ndim == 2:  # assume batch and time are provided
#      24     return x[:, None, :]
#
# File ~/Documents/GitHub/path-shadowing-monte-carlo/.venv/lib/python3.10/site-packages/pandas/core/series.py:1143, in Series.__getitem__(self, key)
#    1140     key = np.asarray(key, dtype=bool)
#    1141     return self._get_rows_with_mask(key)
# -> 1143 return self._get_with(key)
#
# File ~/Documents/GitHub/path-shadowing-monte-carlo/.venv/lib/python3.10/site-packages/pandas/core/series.py:1153, in Series._get_with(self, key)
#    1148     raise TypeError(
#    1149         "Indexing a Series with DataFrame is not "
#    1150         "supported, use the appropriate DataFrame column"
#    1151     )
#    1152 elif isinstance(key, tuple):
# -> 1153     return self._get_values_tuple(key)
#    1155 elif not is_list_like(key):
#    1156     # e.g. scalars that aren't recognized by lib.is_scalar, GH#32684
#    1157     return self.loc[key]
#
# File ~/Documents/GitHub/path-shadowing-monte-carlo/.venv/lib/python3.10/site-packages/pandas/core/series.py:1193, in Series._get_values_tuple(self, key)
#    1188 if com.any_none(*key):
#    1189     # mpl compat if we look up e.g. ser[:, np.newaxis];
#    1190     #  see tests.series.timeseries.test_mpl_compat_hack
#    1191     # the asarray is needed to avoid returning a 2D DatetimeArray
#    1192     result = np.asarray(self._values[key])
# -> 1193     disallow_ndim_indexing(result)
#    1194     return result
#    1196 if not isinstance(self.index, MultiIndex):
#
# File ~/Documents/GitHub/path-shadowing-monte-carlo/.venv/lib/python3.10/site-packages/pandas/core/indexers/utils.py:341, in disallow_ndim_indexing(result)
#     333 """
#     334 Helper function to disallow multi-dimensional indexing on 1D Series/Index.
#     335
#    (...)
#     338 in GH#30588.
#     339 """
#     340 if np.ndim(result) > 1:
# --> 341     raise ValueError(
#     342         "Multi-dimensional indexing (e.g. `obj[:, None]`) is no longer "
#     343         "supported. Convert to a numpy array before indexing instead."
#     344     )
#
# ValueError: Multi-dimensional indexing (e.g. `obj[:, None]`) is no longer supported. Convert to a numpy array before indexing instead.

# %%
np.array(spx["log_returns"][:126])
# Out:
# array([ 3.11083197e-03,  5.45371888e-04,  3.99321835e-03,  2.87758308e-03,
#         1.74523163e-03, -9.42544644e-03,  8.29145633e-03,  2.42348642e-03,
#        -1.08821263e-02,  1.24221512e-02, -1.06543866e-02, -1.91266573e-02,
#        -2.23897796e-02,  4.58755905e-03, -4.21205785e-03,  4.86828287e-03,
#        -1.18881255e-02, -9.87779905e-03,  1.41653055e-02,  1.28895204e-02,
#        -5.48935038e-03, -3.16358560e-02,  2.89293036e-03, -8.90280310e-03,
#         1.29558418e-02, -2.23506943e-03,  9.63388234e-03, -2.74836612e-03,
#         1.78406535e-02,  4.22900460e-03,  6.56315773e-03,  2.18423486e-03,
#        -1.04640512e-03, -1.21766449e-02,  9.67351970e-03, -2.08320855e-03,
#         1.40439256e-03,  1.01072574e-02,  2.32773100e-03,  4.29109521e-04,
#         3.72915608e-03,  1.39102828e-02, -1.75611432e-04,  1.71127202e-03,
#         4.51435490e-03,  4.03337431e-03, -2.17369570e-04,  4.52092623e-04,
#         7.74901498e-03,  5.80479533e-03, -3.25899127e-04, -5.09942645e-03,
#         5.08235910e-03,  7.14537778e-03, -5.50844789e-03, -1.70562108e-03,
#         7.37450616e-04,  5.66714631e-03,  4.26584629e-05, -3.27824232e-03,
#         7.38645401e-03,  7.89672944e-03,  1.68287888e-03, -5.89404297e-03,
#         3.36866143e-03,  6.66166830e-03,  1.76505086e-03,  6.85166040e-04,
#         1.10883631e-02,  8.42183991e-04, -1.62579824e-02,  4.51114074e-03,
#         8.02604574e-03, -1.01951644e-03,  2.26132064e-03,  7.09826768e-03,
#        -4.30570436e-03, -2.36596402e-02,  6.44195838e-03,  1.28601803e-02,
#        -1.67878101e-02,  1.30352575e-02, -2.41272000e-02, -6.60834180e-03,
#        -3.28884406e-02, -1.54266462e-02,  4.30347041e-02, -3.40307592e-03,
#         1.36459924e-02, -1.22194999e-02, -1.89789814e-02,  1.10875362e-03,
#        -1.42976318e-02, -5.14346886e-03, -3.97557958e-02,  1.49126326e-02,
#        -1.29920463e-02,  3.53874765e-04, -5.67707869e-03,  3.23473118e-02,
#        -1.24518923e-02, -1.73143533e-02,  2.55144281e-02,  4.04319198e-03,
#        -3.50174421e-02, -1.36244662e-02,  1.09162676e-02, -5.95939674e-03,
#         2.90798457e-02,  4.37011574e-03, -1.80629393e-03,  2.32224506e-02,
#        -5.56089354e-04,  1.28218581e-03,  1.31626414e-03, -3.86429794e-03,
#        -1.62012251e-02, -2.98993926e-03, -1.69462832e-02,  2.85528193e-03,
#        -2.03600961e-03, -3.15082303e-02, -1.01644540e-02, -3.24571331e-03,
#        -4.67327175e-03,  5.34472589e-03])
